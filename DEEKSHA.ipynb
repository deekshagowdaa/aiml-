# %% [markdown]
# <a href="https://colab.research.google.com/github/deekshagowdaa/aiml-/blob/main/DEEKSHA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <div class="markdown-google-sans">
#   <h2>Explore the Gemini API</h2>
#   <p>The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#   </p>
#   <strong>How to get started</strong>
#     <ol>
#       <li>Go to <a href="https://aistudio.google.com/">Google AI Studio</a> and log in with your Google account.</li>
#       <li><a href="https://aistudio.google.com/app/apikey">Create an API key</a>.</li>
#       <li>Use a quickstart for <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Prompting.ipynb">Python</a>, or call the REST API using <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb">curl</a>.</li>
#       </ol>
#   <strong>Explore use cases</strong>
#     <ul>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Market_a_Jet_Backpack.ipynb">Create a marketing campaign</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Audio.ipynb">Analyze audio recordings</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/System_instructions.ipynb">Use System instructions in chat</a></li>
#     </ul>
#   <p>To learn more, check out the <a href="https://github.com/google-gemini/cookbook">Gemini cookbook</a> or visit the <a href="https://ai.google.dev/docs/">Gemini API documentation</a>.
#   </p>
# </div>

# %%
import pandas as pd

# %%
path="/content/TATA motors.zip"
df=pd.read_csv(path)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f684fc8f8261> in <cell line: 2>()
#       1 path="/content/TATA motors.zip"
# ----> 2 df=pd.read_csv(path)
#       3 df.head(10)
#
# NameError: name 'pd' is not defined

# %%
df.tail(10)
# Out:
#             Open        High         Low       Close
# 3322  624.950012  630.450012  622.150024  628.500000
# 3323  629.950012  630.799988  619.349976  621.450012
# 3324  625.000000  626.500000  615.500000  620.650024
# 3325  623.000000  626.000000  619.500000  624.900024
# 3326  626.900024  627.000000  617.150024  618.500000
# 3327  620.400024  620.849976  607.000000  612.099976
# 3328  614.000000  625.299988  610.150024  620.599976
# 3329  622.650024  623.599976  616.200012  621.650024
# 3330  621.000000  631.000000  617.700012  625.750000
# 3331  627.950012  634.450012  626.250000  629.250000

# %%
df.sum()
# Out:
# Open     1.078064e+06
# High     1.093426e+06
# Low      1.060914e+06
# Close    1.076525e+06
# dtype: float64

# %%
df.min()
# Out:
# Open     66.500000
# High     66.900002
# Low      63.500000
# Close    65.300003
# dtype: float64

# %%
df.max()
# Out:
# Open     629.950012
# High     634.799988
# Low      626.250000
# Close    629.250000
# dtype: float64

# %%
df.count()
# Out:
# Open     3332
# High     3332
# Low      3332
# Close    3332
# dtype: int64

# %%
grouped = df.groupby('Low')
print(grouped.agg({'Open':sum}))
# Out:
#                   Open
# Low
# 63.500000    69.900002
# 64.800003    66.900002
# 65.400002    66.500000
# 66.000000    70.000000
# 66.900002    68.550003
# ...                ...
# 617.700012  621.000000
# 619.349976  629.950012
# 619.500000  623.000000
# 622.150024  624.950012
# 626.250000  627.950012
#
# [2926 rows x 1 columns]

# %%
import pandas as pd
#read CSV file into Dataframe
d=pd.read_csv('/content/TATA motors (1).zip')
d['High'] = d['High'].map(lambda x:x*3.5)
print(d)
# Out:
#             Open         High         Low       Close
# 0     153.988327   542.283441  150.386948  152.098587
# 1     148.803925   528.016517  140.730530  142.066193
# 2     143.461227   508.797653  138.959518  140.710739
# 3     139.503677   492.972351  132.874786  137.396286
# 4     136.080399   500.971573  134.230240  142.442169
# ...          ...          ...         ...         ...
# 3327  620.400024  2172.974916  607.000000  612.099976
# 3328  614.000000  2188.549958  610.150024  620.599976
# 3329  622.650024  2182.599916  616.200012  621.650024
# 3330  621.000000  2208.500000  617.700012  625.750000
# 3331  627.950012  2220.575042  626.250000  629.250000
#
# [3332 rows x 4 columns]

# %%
filtered_d = d[d['Open'].map(lambda x:x>5)]
print(filtered_d)
# Out:
#             Open         High         Low       Close
# 0     153.988327   542.283441  150.386948  152.098587
# 1     148.803925   528.016517  140.730530  142.066193
# 2     143.461227   508.797653  138.959518  140.710739
# 3     139.503677   492.972351  132.874786  137.396286
# 4     136.080399   500.971573  134.230240  142.442169
# ...          ...          ...         ...         ...
# 3327  620.400024  2172.974916  607.000000  612.099976
# 3328  614.000000  2188.549958  610.150024  620.599976
# 3329  622.650024  2182.599916  616.200012  621.650024
# 3330  621.000000  2208.500000  617.700012  625.750000
# 3331  627.950012  2220.575042  626.250000  629.250000
#
# [3332 rows x 4 columns]

# %%
import pandas as pd
from functools import reduce
d=pd.read_csv('/content/TATA motors (1).zip')
total_sum_reduce=(lambda x,y:x+y,d['High'])
print(total_sum_reduce)
# Out:
# (<function <lambda> at 0x78fb5163e9e0>, 0       154.938126
# 1       150.861862
# 2       145.370758
# 3       140.849243
# 4       143.134735
#            ...
# 3327    620.849976
# 3328    625.299988
# 3329    623.599976
# 3330    631.000000
# 3331    634.450012
# Name: High, Length: 3332, dtype: float64)

# %% [markdown]
# BAR PLOT 1

# %%
import pandas as pd
df=pd.read_csv('/content/TATA motors (1).zip')
import matplotlib.pyplot as plt
plt.plot(d['High'],d['Low'],marker='o',linestyle='-',color='green')
plt.title("LINE PLOT")
plt.xlabel('High')
plt.ylabel('Low')
plt.show()

import pandas as pd

# %% [markdown]
# BAR PLOT 2

# %%
import pandas as pd
df=pd.read_csv('/content/TATA motors (1).zip')
import matplotlib.pyplot as plt
df.groupby('Open')['High'].sum().plot(kind='bar')
plt.title("BAR PLOT")
plt.xlabel("Open")
plt.ylabel("High")
plt.show()

# %% [markdown]
# BAR PLOT 3

# %%
plt.hist(df['High'],bins=2,edgecolor='Black')
plt.title("Histogram")
plt.xlabel("Open")
plt.ylabel("Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5b64911574d1> in <cell line: 1>()
# ----> 1 plt.hist(d['High'],bins=2,edgecolor='Black')
#       2 plt.title("Histogram")
#       3 plt.xlabel("Open")
#       4 plt.ylabel("Frequency")
#       5 plt.show()
#
# NameError: name 'd' is not defined

# %% [markdown]
# 4

# %% [markdown]
# BOX PLOT

# %%
plt.scatter(d['High'],d['Close'])
plt.title("SCATTER PLOT")
plt.xlabel('High')
plt.ylabel('Close')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-74358a1bbfff> in <cell line: 1>()
# ----> 1 d.boxplot(column='High')
#       2 plt.title("BOX PLOT")
#       3 plt.ylabel("High")
#       4 plt.show()
#
# NameError: name 'd' is not defined

# %%
df.boxplot(column='High')
plt.title("BOX PLOT")
plt.ylabel('High')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9d13bbbf68ac> in <cell line: 1>()
# ----> 1 df,boxplot(column='High')
#       2 plt.title("BOX PLOT")
#       3 plt.ylabel('High')
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# PIE CHART

# %%
plt.pie(df['Close'],labels=df['Close'])
plt.title('PIE chart')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-894d74d863bc> in <cell line: 1>()
# ----> 1 plt.pie(df['Close'],labels=df['Close'])
#       2 plt.title('PIE chart')
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %%
import pandas as pd

# %%
path="/content/TATA motors (1).zip"
df=pd.read_csv(path)
df.head(6)
# Out:
#          Open        High         Low       Close
# 0  153.988327  154.938126  150.386948  152.098587
# 1  148.803925  150.861862  140.730530  142.066193
# 2  143.461227  145.370758  138.959518  140.710739
# 3  139.503677  140.849243  132.874786  137.396286
# 4  136.080399  143.134735  134.230240  142.442169
# 5  144.450623  146.429398  139.513580  140.384232

# %%
import pandas as pd
df=pd.read_csv('/content/TATA motors (1).zip')
import matplotlib.pyplot as plt
plt.hist(df['Open'],edgecolor='black')
plt.title("histogram")
plt.xlabel('Open')
plt.ylabel('frequency')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/TATA motors (1).zip')
import matplotlib.pyplot as plt
df.boxplot(column=['Close'])
plt.title("box plot")
plt.ylabel('Close')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-636c5f1f747d> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('/content/TATA motors (1).zip')
#       3 import matplotlib.pyplot as plt
#       4 df.boxplot(column=['Close'])
#       5 plt.title("box plot")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     780             # "Union[str, BaseBuffer]"; expected "Union[Union[str, PathLike[str]],
#     781             # ReadBuffer[bytes], WriteBuffer[bytes]]"
# --> 782             handle = _BytesZipFile(
#     783                 handle, ioargs.mode, **compression_args  # type: ignore[arg-type]
#     784             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in __init__(self, file, mode, archive_name, **kwargs)
#    1023         # Union[str, PathLike[str]], ReadBuffer[bytes], WriteBuffer[bytes]]";
#    1024         # expected "Union[Union[str, PathLike[str]], IO[bytes]]"
# -> 1025         self.buffer = zipfile.ZipFile(file, mode, **kwargs)  # type: ignore[arg-type]
#    1026
#    1027     def infer_filename(self) -> str | None:
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1251             while True:
#    1252                 try:
# -> 1253                     self.fp = io.open(file, filemode)
#    1254                 except OSError:
#    1255                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/TATA motors (1).zip'

# %%
import pandas as pd
df=pd.read_csv('/content/TATA motors (1).zip')
import matplotlib.pyplot as plt
plt.pie(df['Low'],labels=df['High'])
plt.title("pie chart")
plt.show()
